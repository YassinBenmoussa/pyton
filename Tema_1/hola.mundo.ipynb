# %% [markdown]
# # Primer programa
# ## Hola mundo

# %%
print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# ### Ejemplo de indentación

# %%
nombre = "Yasin"
if(nombre == "Yasin")
print("Hola Yasin")
print("estoy dentro de if")
else:
print("Hola, ¿cómo te llamas?")
# Out:
#   Cell In[8], line 2
#     if(nombre == "Yasin")
#                          ^
# SyntaxError: expected ':'

# %% [markdown]
# ### Comentarios de código

# %%
# ------------ Este print diráque sí --------------
# print("Este no quiero que se imprima")
print("Este sí")

# %% [markdown]
# # Funciones

# %%
def me_puedo_ir_a_casa(hora_en_num):
    """function: me_puedo_ir_a_casa
    compara si la hora pasada como argumento es mayor que un número e imprime por pantalla Sí o No
    arg1: hora_en_num: int
    """
    if(hora_en_num) >= 14):
print("Sí :)")
else:

print("no:(")
# Out:
#   Cell In[9], line 2
#     if(hora_en_num) >= 14):
#                          ^
# SyntaxError: unmatched ')'
